# %%
import numpy as np
import seaborn as sns
import os

#CMPA数据：
#经度 97.05 到 122.4 一共508格点   纬度 17.2到30.4 一共265格点

# %%
infolder = '/home/lzhou/Precipitation/cmpa/cmpa_3km/202105'
files = os.listdir(infolder)

# %%
infile = os.path.join(infolder,files[0])
test = np.load(infile)

# %%
test.shape
# Out:
# (265, 508)

# %%
sns.heatmap(test)
# Out:
# <AxesSubplot:>
